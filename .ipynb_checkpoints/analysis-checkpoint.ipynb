# %% [markdown]
# # Celdas de pruebas

# %%
import datacube
dc = datacube.Datacube(app = "first")

# %%
xarr = dc.load(
    # Satellite 
    product="s2a_sen2cor_granule", output_crs='EPSG:4326', resolution=(-0.001,0.001)
    # Area to be requested 
    # The query return the images that were obtained 
    # in the time range specified
    # Time format (YYYY-MM-DD)
)

# %%
print(min( sentinel_dataset.geobox.extent.envelope.geom.exterior.coords.xy[0]))
# Out:
# -76.1101

# %%
df=dc.find_datasets(product="s2a_sen2cor_granule")
df
# Out:
# [Dataset <id=74a9f0b7-c8e2-46e3-893a-ca969ce012b2 product=s2a_sen2cor_granule location=file:///C:/Users/saraPC/Documents/Univerisdad/MONITORI/opendatacube/output/S2A_MSIL2A_20200322T153621_N0214_R068_T18NUL_20200322T193833.yaml>,
#  Dataset <id=9664b744-2756-4a3c-ad46-7777e99725ce product=s2a_sen2cor_granule location=file:///C:/Users/saraPC/Documents/Univerisdad/MONITORI/opendatacube/output/S2A_MSIL2A_20200322T153621_N0214_R068_T18NUL_20200322T193833.yaml>]

# %% [markdown]
# # Proceso de análisis de imagenes

# %%
import numpy as np
import xarray as xr
import pandas as pd
import matplotlib.pyplot as plt

# Load Data Cube Configuration
import datacube
import utils.data_cube_utilities.data_access_api as dc_api  
api = dc_api.DataAccessApi()
dc= api.dc

# %%
product = "s2a_sen2cor_granule"
platform = "SENTINEL_2A"

# %%
from utils.data_cube_utilities.dc_load import get_product_extents
from utils.data_cube_utilities.dc_time import dt_to_str

full_lat, full_lon, min_max_dates = get_product_extents(api, platform, product,output_crs='EPSG:4326', resolution=(-0.00001,0.00001))

# Print the extents of the combined data.
print("Latitude Extents:", full_lat)
print("Longitude Extents:", full_lon)
print("Time Extents:", list(map(dt_to_str, min_max_dates)))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-78-3d5c19b866e6> in <module>
#       2 from utils.data_cube_utilities.dc_time import dt_to_str
#       3
# ----> 4 full_lat, full_lon, min_max_dates = get_product_extents(api, platform, product,output_crs='EPSG:4326', resolution=(-0.00001,0.00001))
#       5
#       6 # Print the extents of the combined data.
#
# ~\Documents\Univerisdad\MONITORI\opendatacube\Sentinel\utils\data_cube_utilities\dc_load.py in get_product_extents(api, platform, product, **kwargs)
#     487     """
#     488     # Get the extents of the cube
# --> 489     descriptor = api.get_query_metadata(platform=platform, product=product, **kwargs)
#     490     min_max_lat = descriptor['lat_extents']
#     491     min_max_lon = descriptor['lon_extents']
#
# ~\Documents\Univerisdad\MONITORI\opendatacube\Sentinel\utils\data_cube_utilities\data_access_api.py in get_query_metadata(self, product, platform, longitude, latitude, time, **kwargs)
#     193             }
#     194         coordinates=dataset.geobox.extent.envelope.geom.exterior.coords.xy[0]
# --> 195         lon_min=min(dataset.geobox.extent.envelope.geom.exterior.coords.xy[0])
#     196         lon_max=max(dataset.geobox.extent.envelope.geom.exterior.coords.xy[0])
#     197         lat_max=max(coordinates[1])
#
# ~\Anaconda3\envs\cubeenv\lib\site-packages\datacube\utils\geometry\_base.py in __iter__(self)
#     688
#     689     def __iter__(self) -> Iterator['Geometry']:
# --> 690         for geom in self.geom:
#     691             yield Geometry(geom, self.crs)
#     692
#
# TypeError: 'Polygon' object is not iterable

# %%
from utils.data_cube_utilities.dc_display_map import display_map
full_lat = (4.45, 4.84)
full_lon= (-74.99, -75.8)
display_map(full_lat, full_lon)
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
# Phu Thuy, Vietnam
latitude = (4.76, 4.84)
longitude = (-75.91, -75.8)


# Time Period
time_extents = ('2019-04-1', '2020-04-1')

# %%
from utils.data_cube_utilities.dc_display_map import display_map
display_map(latitude,longitude)
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
sentinel_dataset = dc.load(latitude = latitude,
                          longitude = longitude,
                          platform = platform,
                          product = product,
                          measurements = ['B04_10m', 'B03_10m', 'B02_10m', 'B08_10m', 'B11_20m', 'B12_20m'], output_crs='EPSG:4326', resolution=(-0.00011,0.00011))

# %%
sentinel_dataset
# Out:
# <xarray.Dataset>
# Dimensions:      (latitude: 728, longitude: 1001, time: 1)
# Coordinates:
#   * time         (time) datetime64[ns] 2020-03-22T15:39:01.832211
#   * latitude     (latitude) float64 4.84 4.84 4.84 4.84 ... 4.76 4.76 4.76 4.76
#   * longitude    (longitude) float64 -76.11 -76.11 -76.11 ... -76.0 -76.0 -76.0
#     spatial_ref  int32 4326
# Data variables:
#     B04_10m      (time, latitude, longitude) uint16 211 200 203 ... 573 393 449
#     B03_10m      (time, latitude, longitude) uint16 427 413 447 ... 589 486 545
#     B02_10m      (time, latitude, longitude) uint16 167 162 172 ... 333 238 268
#     B08_10m      (time, latitude, longitude) uint16 3669 3648 3814 ... 2418 2789
#     B11_20m      (time, latitude, longitude) uint16 1708 1752 1752 ... 2583 2583
#     B12_20m      (time, latitude, longitude) uint16 690 715 715 ... 1382 1382
# Attributes:
#     crs:           EPSG:4326
#     grid_mapping:  spatial_ref

# %%
first_timestep = sentinel_dataset.B03_10m.isel(time=0)
first_timestep.plot(robust=True, cmap="plasma")

# %%
#Si se tienen varias imagenes del mismo lugar en el mismo tiempo se puede visualizar asi
first_timestep = sentinel_dataset.B03_10m.plot(col="time")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-144-0c79599b5c94> in <module>
# ----> 1 first_timestep = sentinel_dataset.B03_10m.plot(col="time")
#
# ~\Anaconda3\envs\cubeenv\lib\site-packages\xarray\plot\plot.py in __call__(self, **kwargs)
#     444
#     445     def __call__(self, **kwargs):
# --> 446         return plot(self._da, **kwargs)
#     447
#     448     @functools.wraps(hist)
#
# ~\Anaconda3\envs\cubeenv\lib\site-packages\xarray\plot\plot.py in plot(darray, row, col, col_wrap, ax, hue, rtol, subplot_kws, **kwargs)
#     198     kwargs["ax"] = ax
#     199
# --> 200     return plotfunc(darray, **kwargs)
#     201
#     202
#
# ~\Anaconda3\envs\cubeenv\lib\site-packages\xarray\plot\plot.py in newplotfunc(darray, x, y, figsize, size, aspect, ax, row, col, col_wrap, xincrease, yincrease, add_colorbar, add_labels, vmin, vmax, cmap, center, robust, extend, levels, infer_intervals, colors, subplot_kws, cbar_ax, cbar_kwargs, xscale, yscale, xticks, yticks, xlim, ylim, norm, **kwargs)
#     631             # Need the decorated plotting function
#     632             allargs["plotfunc"] = globals()[plotfunc.__name__]
# --> 633             return _easy_facetgrid(darray, kind="dataarray", **allargs)
#     634
#     635         plt = import_matplotlib_pyplot()
#
# ~\Anaconda3\envs\cubeenv\lib\site-packages\xarray\plot\facetgrid.py in _easy_facetgrid(data, plotfunc, kind, x, y, row, col, col_wrap, sharex, sharey, aspect, size, subplot_kws, ax, figsize, **kwargs)
#     633         aspect=aspect,
#     634         size=size,
# --> 635         subplot_kws=subplot_kws,
#     636     )
#     637
#
# ~\Anaconda3\envs\cubeenv\lib\site-packages\xarray\plot\facetgrid.py in __init__(self, data, col, row, col_wrap, sharex, sharey, figsize, aspect, size, subplot_kws)
#     117
#     118         # Handle corner case of nonunique coordinates
# --> 119         rep_col = col is not None and not data[col].to_index().is_unique
#     120         rep_row = row is not None and not data[row].to_index().is_unique
#     121         if rep_col or rep_row:
#
# ~\Anaconda3\envs\cubeenv\lib\site-packages\xarray\core\dataarray.py in to_index(self)
#     570         arrays.
#     571         """
# --> 572         return self.variable.to_index()
#     573
#     574     @property
#
# ~\Anaconda3\envs\cubeenv\lib\site-packages\xarray\core\variable.py in to_index(self)
#     468     def to_index(self):
#     469         """Convert this variable to a pandas.Index"""
# --> 470         return self.to_index_variable().to_index()
#     471
#     472     def to_dict(self, data=True):
#
# ~\Anaconda3\envs\cubeenv\lib\site-packages\xarray\core\variable.py in to_index_variable(self)
#     461         """Return this variable as an xarray.IndexVariable"""
#     462         return IndexVariable(
# --> 463             self.dims, self._data, self._attrs, encoding=self._encoding, fastpath=True
#     464         )
#     465
#
# ~\Anaconda3\envs\cubeenv\lib\site-packages\xarray\core\variable.py in __init__(self, dims, data, attrs, encoding, fastpath)
#    2086         super().__init__(dims, data, attrs, encoding, fastpath)
#    2087         if self.ndim != 1:
# -> 2088             raise ValueError("%s objects must be 1-dimensional" % type(self).__name__)
#    2089
#    2090         # Unlike in Variable, always eagerly load values into memory
#
# ValueError: IndexVariable objects must be 1-dimensional

# %%
from utils.dea_plotting import rgb

# %% [markdown]
# # True Color Image

# %%
rgb(sentinel_dataset, bands=["B04_10m", "B03_10m", "B02_10m"], index=0)

# %%
rgb(sentinel_dataset, bands=["B04_10m", "B03_10m", "B02_10m"], percentile_stretch=[0.05, 0.95])

# %% [markdown]
# # False color (emphasises growing vegetation in green, and water in deep blue)

# %%
rgb(sentinel_dataset, bands=["B11_20m", "B08_10m", "B03_10m"], index=0)

# %%
# Calculate the components that make up the NDVI calculation
band_diff = sentinel_dataset.B08_10m- sentinel_dataset.B04_10m
band_sum = sentinel_dataset.B08_10m + sentinel_dataset.B04_10m

# Calculate NDVI and store it as a measurement in the original dataset
ndvi = band_diff / band_sum
ndvi.plot()

# %%
# Set the NDVI time step to view
ndvi_time_step = 0

# This is the simple way to plot
# Note that high values are likely to be vegetation.
plt.figure(figsize=(10, 10))
ndvi.isel(time=ndvi_time_step).plot(cmap="RdYlGn")
plt.show()

# %%
from utils.data_cube_utilities.clean_mask import sentinel2_fmask_clean_mask

cloud_mask = sentinel2_fmask_clean_mask(sentinel_dataset)
land_mask = sentinel2_fmask_clean_mask(sentinel_dataset, cover_types=['valid'])

# Land and Water Dataset = Land and Water pixels with NO Clouds and NO Cloud Shadows
land_and_water_dataset = landsat_dataset.where(cloud_mask)

# Land Dataset = Land ONLY pixels with NO Clouds, NO Cloud Shadows and NO Water pixels
land_dataset = landsat_dataset.where(land_mask)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-27-88a853dfc218> in <module>
#       1 from utils.data_cube_utilities.clean_mask import sentinel2_fmask_clean_mask
#       2
# ----> 3 cloud_mask = sentinel2_fmask_clean_mask(sentinel_dataset)
#       4 land_mask = sentinel2_fmask_clean_mask(sentinel_dataset, cover_types=['valid'])
#       5
#
# ~\Documents\Univerisdad\MONITORI\opendatacube\utils\data_cube_utilities\clean_mask.py in sentinel2_fmask_clean_mask(dataset, cover_types)
#     227     fmask_table = {'null': 0, 'valid': 1, 'cloud': 2, 'cloud_shadow': 3, 'snow': 4, 'water': 5}
#     228     fmask_values_to_keep = [fmask_table[cover_type] for cover_type in cover_types]
# --> 229     clean_mask = xarray_values_in(dataset.fmask, fmask_values_to_keep)
#     230     return clean_mask
#     231
#
# ~\Anaconda3\envs\cubeenv\lib\site-packages\xarray\core\common.py in __getattr__(self, name)
#     231                     return source[name]
#     232         raise AttributeError(
# --> 233             "{!r} object has no attribute {!r}".format(type(self).__name__, name)
#     234         )
#     235
#
# AttributeError: 'Dataset' object has no attribute 'fmask'
